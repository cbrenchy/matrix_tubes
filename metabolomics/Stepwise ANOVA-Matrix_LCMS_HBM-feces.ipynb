# %% [markdown]
# # Set up notebook environment
# ## NOTE: Use a QIIME2 kernel

# %%
import os
import biom
import warnings
import pickle
import numpy as np
import pandas as pd
import qiime2 as q2
from biom import Table
from skbio import OrdinationResults
from skbio.stats import subsample_counts
from skbio.stats.distance import permanova, anosim, mantel
from skbio.stats.distance import DistanceMatrix
from qiime2.plugins.deicode.actions import rpca
from qiime2.plugins.feature_table.actions import rarefy
from qiime2.plugins.diversity.actions import beta_group_significance
from qiime2.plugins.emperor.actions import biplot, plot
from qiime2.plugins.diversity.actions import (beta,
                                              beta_phylogenetic,
                                              pcoa)
from qiime2.plugins import demux, deblur, quality_filter, \
                           metadata, feature_table, alignment, \
                           phylogeny, diversity, emperor, feature_classifier, \
                           taxa, composition

from assets.step_wise_anova import run_stepwise_anova
from qiime2.plugins.fragment_insertion.actions import filter_features
warnings.filterwarnings("ignore", category=DeprecationWarning)

# helper functions
from assets.util import (mantel_matched, simulate_depth,
                        all_dists, nested_permanova)

# plotting
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# # Subset metadata to make paired files between extraction kits

# %%
SEQ_TYPE='shotgun'

# %%
# Read in sample metadata
md = pd.read_csv('HBM_Matrix_LCMS_1500/metadata_ms_HBM.tsv'.format(SEQ_TYPE=SEQ_TYPE), sep = '\t')
md = md[(md['ATTRIBUTE_type'] == 'feces')]
md.to_csv('HBM_Matrix_LCMS_1500/metadata_feces.tsv', sep='\t', index=False)
md
# Out:
#     sample_name                        filename ATTRIBUTE_storagebuffer  \
# 36    363193206  363193206_GA11_01_64746.mzXML              isopropanol
# 37    363193214  363193214_GB10_01_64758.mzXML              isopropanol
# 38    363193215  363193215_GB11_01_64759.mzXML              isopropanol
# 39    363193225  363193225_GC10_01_64771.mzXML              isopropanol
# 40    363193232  363193232_GG11_01_64824.mzXML              isopropanol
# 41    363193235  363193235_GA12_01_64747.mzXML              isopropanol
# 42    363193242  363193242_GH11_01_64838.mzXML              isopropanol
# 43    363193260  363193260_GF12_01_64812.mzXML              isopropanol
# 44    363193261  363193261_GG12_01_64825.mzXML              isopropanol
# 45    363193268  363193268_GH10_01_64836.mzXML              isopropanol
# 46    363193269  363193269_GA10_01_64745.mzXML              isopropanol
# 47    363193276  363193276_GH12_01_64839.mzXML              isopropanol
# 48    363193575  363193575_GE12_01_64799.mzXML                     etoh
# 49    363193577  363193577_GF11_01_64811.mzXML                     etoh
# 50    363193584   363193584_GG9_01_64822.mzXML                     etoh
# 51    363193585  363193585_GG10_01_64823.mzXML                     etoh
# 52    363193593  363193593_GD12_01_64786.mzXML                     etoh
# 53    363193594   363193594_GH9_01_64835.mzXML                     etoh
# 54    363193595  363193595_GF10_01_64810.mzXML                     etoh
# 55    363193596  363193596_GE11_01_64798.mzXML                     etoh
# 56    363193602   363193602_GE9_01_64796.mzXML                     etoh
# 57    363193603  363193603_GD10_01_64784.mzXML                     etoh
# 58    363193604  363193604_GC11_01_64772.mzXML                     etoh
# 59    363193613  363193613_GB12_01_64760.mzXML                     etoh
# 60    363197846   363197846_GE1_01_64788.mzXML              isopropanol
# 61    363197847   363197847_GF1_01_64801.mzXML              isopropanol
# 62    363197866   363197866_GB1_01_64749.mzXML                     etoh
# 63    363197878   363197878_GF3_01_64803.mzXML                     etoh
# 64    363197879   363197879_GG3_01_64816.mzXML                     etoh
# 65    363197880   363197880_GC4_01_64765.mzXML              isopropanol
# 66    363197881   363197881_GA4_01_64739.mzXML              isopropanol
# 67    363197883   363197883_GA1_01_64736.mzXML                     etoh
# 68    363197885   363197885_GC1_01_64762.mzXML                     etoh
# 69    363197888   363197888_GA7_01_64781.mzXML                     etoh
# 70    363197889   363197889_GE7_01_64794.mzXML              isopropanol
# 71    363197891   363197891_GD1_01_64775.mzXML              isopropanol
# 72    363198182   363198182_GA5_01_64740.mzXML              isopropanol
# 73    363198183   363198183_GB5_01_64753.mzXML              isopropanol
# 74    363198184   363198184_GB4_01_64752.mzXML              isopropanol
# 75    363198185   363198185_GH3_01_64829.mzXML                     etoh
# 76    363198186   363198186_GF4_01_64804.mzXML                     etoh
# 77    363198187   363198187_GE4_01_64791.mzXML                     etoh
# 78    363198188   363198188_GG4_01_64817.mzXML                     etoh
# 79    363198189   363198189_GH4_01_64830.mzXML              isopropanol
# 80    363198194   363198194_GG7_01_64820.mzXML              isopropanol
# 81    363198195   363198195_GC7_01_64768.mzXML                     etoh
# 82    363198196   363198196_GF7_01_64807.mzXML              isopropanol
# 83    363198197   363198197_GB7_01_64755.mzXML                     etoh
#
#    ATTRIBUTE_extraction_protocol ATTRIBUTE_type ATTRIBUTE_host_subject_id  \
# 36                        Matrix          feces                    mouse2
# 37                        Matrix          feces                    mouse1
# 38                        Matrix          feces                    mouse2
# 39                        Matrix          feces                    mouse1
# 40                        Matrix          feces                    mouse3
# 41                        Matrix          feces                    mouse3
# 42                        Matrix          feces                    mouse3
# 43                        Matrix          feces                    mouse4
# 44                        Matrix          feces                    mouse4
# 45                        Matrix          feces                    mouse2
# 46                        Matrix          feces                    mouse1
# 47                        Matrix          feces                    mouse4
# 48                        Matrix          feces                    mouse4
# 49                        Matrix          feces                    mouse3
# 50                        Matrix          feces                    mouse1
# 51                        Matrix          feces                    mouse2
# 52                        Matrix          feces                    mouse4
# 53                        Matrix          feces                    mouse1
# 54                        Matrix          feces                    mouse2
# 55                        Matrix          feces                    mouse3
# 56                        Matrix          feces                    mouse1
# 57                        Matrix          feces                    mouse2
# 58                        Matrix          feces                    mouse3
# 59                        Matrix          feces                    mouse4
# 60                        Matrix          feces                         A
# 61                        Matrix          feces                         A
# 62                        Matrix          feces                         A
# 63                        Matrix          feces                         B
# 64                        Matrix          feces                         B
# 65                        Matrix          feces                         B
# 66                        Matrix          feces                         B
# 67                        Matrix          feces                         A
# 68                        Matrix          feces                         A
# 69                        Matrix          feces                         D
# 70                        Matrix          feces                         D
# 71                        Matrix          feces                         A
# 72                        Matrix          feces                         C
# 73                        Matrix          feces                         C
# 74                        Matrix          feces                         B
# 75                        Matrix          feces                         B
# 76                        Matrix          feces                         C
# 77                        Matrix          feces                         C
# 78                        Matrix          feces                         C
# 79                        Matrix          feces                         C
# 80                        Matrix          feces                         D
# 81                        Matrix          feces                         D
# 82                        Matrix          feces                         D
# 83                        Matrix          feces                         D
#
#    ATTRIBUTE_sample_type2
# 36            mouse_feces
# 37            mouse_feces
# 38            mouse_feces
# 39            mouse_feces
# 40            mouse_feces
# 41            mouse_feces
# 42            mouse_feces
# 43            mouse_feces
# 44            mouse_feces
# 45            mouse_feces
# 46            mouse_feces
# 47            mouse_feces
# 48            mouse_feces
# 49            mouse_feces
# 50            mouse_feces
# 51            mouse_feces
# 52            mouse_feces
# 53            mouse_feces
# 54            mouse_feces
# 55            mouse_feces
# 56            mouse_feces
# 57            mouse_feces
# 58            mouse_feces
# 59            mouse_feces
# 60            human_feces
# 61            human_feces
# 62            human_feces
# 63            human_feces
# 64            human_feces
# 65            human_feces
# 66            human_feces
# 67            human_feces
# 68            human_feces
# 69            human_feces
# 70            human_feces
# 71            human_feces
# 72            human_feces
# 73            human_feces
# 74            human_feces
# 75            human_feces
# 76            human_feces
# 77            human_feces
# 78            human_feces
# 79            human_feces
# 80            human_feces
# 81            human_feces
# 82            human_feces
# 83            human_feces

# %% [markdown]
# # Stepwise RDA

# %% [markdown]
# ## Shotgun data

# %%
# Import data
md_round1and2_bothPS_q2 = q2.Metadata.load('HBM_Matrix_LCMS_1500/metadata_feces.tsv')

# %%
md_round1and2_bothPS_q2
# Out:
# Metadata
# --------
# 48 IDs x 6 columns
# filename:                      ColumnProperties(type='categorical')
# ATTRIBUTE_storagebuffer:       ColumnProperties(type='categorical')
# ATTRIBUTE_extraction_protocol: ColumnProperties(type='categorical')
# ATTRIBUTE_type:                ColumnProperties(type='categorical')
# ATTRIBUTE_host_subject_id:     ColumnProperties(type='categorical')
# ATTRIBUTE_sample_type2:        ColumnProperties(type='categorical')
#
# Call to_dataframe() for a tabular representation.

# %%
# Filter table
# table_shotgun_biom = table_shotgun.view(Table)
md_round1and2_bothPS_df = md_round1and2_bothPS_q2.to_dataframe()
# shared_ = list(set(table_shotgun_biom.ids()) & set(md_round1and2_bothPS_df.index))
md_round1and2_bothPS_df_shotgun = md_round1and2_bothPS_df#.reindex(shared_)
# table_shotgun_biom_bothPS = table_shotgun_biom.filter(shared_)
# keep_ = table_shotgun_biom_bothPS.ids('observation')[table_shotgun_biom_bothPS.sum('observation') > 0]
# table_shotgun_biom_bothPS.filter(keep_, axis='observation')

# # Import filtered table and re-indexed metadata file
# table_shotgun_bothPS = q2.Artifact.import_data('FeatureTable[Frequency]', table_shotgun_biom_bothPS)
md_round1and2_bothPS_df_shotgun_q2 = q2.Metadata(md_round1and2_bothPS_df_shotgun)

# # Generate distance matrices using 'all_dissts' utils
# rare_depth_shotgun = 1000
# dists_res_shotgun = all_dists(table_shotgun_bothPS,
#                       rare_depth_shotgun, tree_shotgun)

# Generate ordinations (row=samples, cols=axes)
pcoa_res_shotgun = {}
# pcoa_res_shotgun['Jaccard'] = pcoa(dists_res_shotgun['Jaccard'].distance_matrix).pcoa.view(OrdinationResults).samples
# pcoa_res_shotgun['Unweighted UniFrac'] = pcoa(dists_res_shotgun['Unweighted UniFrac'].distance_matrix).pcoa.view(OrdinationResults).samples
# pcoa_res_shotgun['Weighted UniFrac'] = pcoa(dists_res_shotgun['Weighted UniFrac'].distance_matrix).pcoa.view(OrdinationResults).samples
# pcoa_res_shotgun['RPCA'] = dists_res_shotgun['RPCA'].biplot.view(OrdinationResults).samples
distance_matrix_Jaccard = q2.Artifact.load('HBM_Matrix_LCMS_1500/distance_matrix1500_jaccard_qiime2_noise_detect2_noblanks_HBM_R.qza')
pcoa_res_shotgun['Jaccard'] = pcoa(distance_matrix_Jaccard).pcoa.view(OrdinationResults).samples
distance_matrix_RPCA = q2.Artifact.load('HBM_Matrix_LCMS_1500/distance_matrix1500_canberra_qiime2_noise_detect2_noblanks_HBM_R.qza')
pcoa_res_shotgun['RPCA'] = pcoa(distance_matrix_RPCA).pcoa.view(OrdinationResults).samples
#names = {n: '14332.' + n for n in pcoa_res_shotgun['RPCA'].index} #appending "14332."to sample names in RPCA matrix
#pcoa_res_shotgun['RPCA'].rename(index=names, inplace=True)
#pcoa_res_shotgun["RPCA"] = pcoa_res_shotgun['RPCA'].loc[pcoa_res_shotgun['RPCA'].index.isin(pcoa_res_shotgun['Jaccard'].index)] #grabbing samples from the jaccard matrix only to use in RPCA #grabbing samples from the jaccard matrix only to use in RPCA

# %%
distance_matrix_RPCA
# Out:
# <artifact: DistanceMatrix uuid: c009c2b3-085b-4aac-a8f7-ade21f02e352>

# %%
distance_matrix_Jaccard
# Out:
# <artifact: DistanceMatrix uuid: e4865ce8-fe91-4ddf-95bc-1437d8c6c154>

# %%
# Perform stepwise RDA-ANOVA
es_all = {}
use_ = ['ATTRIBUTE_storagebuffer','ATTRIBUTE_sample_type2', 'ATTRIBUTE_host_subject_id', 'ATTRIBUTE_sample_type2']

# Clean up meta (only stuff to run)
mf_ord = md_round1and2_bothPS_df_shotgun_q2.to_dataframe().copy()
#mf_ord = mf_ord[mf_ord.index.isin(pcoa_res_shotgun['RPCA'].index)]
#mf_ord = mf_ord[mf_ord.index.isin(pcoa_res_shotgun['Jaccard'].index)]

# Filter data
keep_ = [v_ for v_ in mf_ord.columns
         if len(set(mf_ord[v_])) > 1 and
         len(set(mf_ord[v_])) < mf_ord.shape[0]//2]
mf_ord = mf_ord[keep_]
print(len(keep_))
# Run stepwise ANOVA for all RDA ordinations
for metric_, ord_ in  pcoa_res_shotgun.items():
    # get first three axes
    ord_ = ord_[[0,1,2]]
    ord_.columns = ['PC1','PC2','PC3']
    # subset/match
    mf_ord_ = mf_ord.copy()
    shared_ids = list(set(ord_.index)\
                      & set(mf_ord_.index))
    mf_ord_ = mf_ord_.loc[shared_ids,:]
    ord_ = ord_.loc[shared_ids,:]
    es_all[metric_] = run_stepwise_anova(ord_, mf_ord_, use_) #mf_ord_.columns)

# Concat output from all runs and export
es_alldf = pd.concat(es_all) #.rename({'+ sample_type2':'+ sample_type'}, axis=0)
# es_alldf.to_csv('/Users/Justin/Mycelium/UCSD/00_Knight_Lab/03_Extraction_test_12201/round_02/results/stepwise_anova/stepwise_anova_shotgun.txt', sep='\t')
es_alldf
# Out:
# 3
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: /Users/caitrionabrennan/Downloads/assets/stepwise-rda.R /var/folders/lh/d1kdwkz53856l7_mtjyz0f640000gn/T/tmpx683l0n6/ord_.tsv /var/folders/lh/d1kdwkz53856l7_mtjyz0f640000gn/T/tmpx683l0n6/mf_.txt /var/folders/lh/d1kdwkz53856l7_mtjyz0f640000gn/T/tmpx683l0n6/output.effect.size.tsv
#
# R version 4.0.5 (2021-03-31)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.5-7
# Call: rda(formula = Y_16S ~ 1, data = X_16S, scale = TRUE)
#
#               Inertia Rank
# Total               3
# Unconstrained       3    3
# Inertia is correlations
#
# Eigenvalues for unconstrained axes:
#    PC1    PC2    PC3
# 1.8951 0.9358 0.1691
#
# Call: rda(formula = Y_16S ~ ATTRIBUTE_storagebuffer +
# ATTRIBUTE_sample_type2 + ATTRIBUTE_host_subject_id +
# ATTRIBUTE_sample_type2.1, data = X_16S, scale = TRUE)
#
#               Inertia Proportion Rank
# Total          3.0000     1.0000
# Constrained    1.1239     0.3746    3
# Unconstrained  1.8761     0.6254    3
# Inertia is correlations
# Some constraints were aliased because they were collinear (redundant)
#
# Eigenvalues for constrained axes:
#   RDA1   RDA2   RDA3
# 0.7955 0.2781 0.0503
#
# Eigenvalues for unconstrained axes:
#    PC1    PC2    PC3
# 1.2685 0.4965 0.1112
#
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: /Users/caitrionabrennan/Downloads/assets/stepwise-rda.R /var/folders/lh/d1kdwkz53856l7_mtjyz0f640000gn/T/tmpsnnk01hj/ord_.tsv /var/folders/lh/d1kdwkz53856l7_mtjyz0f640000gn/T/tmpsnnk01hj/mf_.txt /var/folders/lh/d1kdwkz53856l7_mtjyz0f640000gn/T/tmpsnnk01hj/output.effect.size.tsv
#
# R version 4.0.5 (2021-03-31)
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.5-7
# Call: rda(formula = Y_16S ~ 1, data = X_16S, scale = TRUE)
#
#               Inertia Rank
# Total               3
# Unconstrained       3    3
# Inertia is correlations
#
# Eigenvalues for unconstrained axes:
#    PC1    PC2    PC3
# 1.4531 0.8689 0.6780
#
# Call: rda(formula = Y_16S ~ ATTRIBUTE_storagebuffer +
# ATTRIBUTE_sample_type2 + ATTRIBUTE_host_subject_id +
# ATTRIBUTE_sample_type2.1, data = X_16S, scale = TRUE)
#
#               Inertia Proportion Rank
# Total          3.0000     1.0000
# Constrained    1.2663     0.4221    3
# Unconstrained  1.7337     0.5779    3
# Inertia is correlations
# Some constraints were aliased because they were collinear (redundant)
#
# Eigenvalues for constrained axes:
#   RDA1   RDA2   RDA3
# 0.9008 0.2309 0.1345
#
# Eigenvalues for unconstrained axes:
#    PC1    PC2    PC3
# 0.6763 0.6119 0.4455
#                                        R2.adj  Df       AIC        F  Pr(>F)
# Jaccard + ATTRIBUTE_host_subject_id  0.239732   7  46.82589  3.11719  0.0012
# RPCA    + ATTRIBUTE_host_subject_id  0.286163   7  43.80114  3.69162  0.0004

# %%
pcoa_res_shotgun["RPCA"].shape,pcoa_res_shotgun["Jaccard"].shape
# Out:
# ((84, 84), (84, 84))

# %%
mf_ord.columns
# Out:
# Index(['ATTRIBUTE_storagebuffer', 'ATTRIBUTE_host_subject_id',
#        'ATTRIBUTE_sample_type2'],
#       dtype='object')

# %%
s1=set(pcoa_res_shotgun['RPCA'].index)

# %%
s2=set(pcoa_res_shotgun['Jaccard'].index)

# %%
s1
# Out:
# {'361162770',
#  '361162771',
#  '361162790',
#  '361162793',
#  '361162798',
#  '361162807',
#  '361162809',
#  '361164071',
#  '361164072',
#  '361164081',
#  '361164082',
#  '361164083',
#  '361164086',
#  '361164090',
#  '361164091',
#  '361164093',
#  '361164094',
#  '361164109',
#  '361164117',
#  '361164176',
#  '361164180',
#  '361164195',
#  '361164201',
#  '361164203',
#  '361164213',
#  '361164223',
#  '361164224',
#  '361164229',
#  '361164231',
#  '361164234',
#  '361164244',
#  '361164250',
#  '361164254',
#  '361164255',
#  '361164259',
#  '361164260',
#  '363193206',
#  '363193214',
#  '363193215',
#  '363193225',
#  '363193232',
#  '363193235',
#  '363193242',
#  '363193260',
#  '363193261',
#  '363193268',
#  '363193269',
#  '363193276',
#  '363193575',
#  '363193577',
#  '363193584',
#  '363193585',
#  '363193593',
#  '363193594',
#  '363193595',
#  '363193596',
#  '363193602',
#  '363193603',
#  '363193604',
#  '363193613',
#  '363197846',
#  '363197847',
#  '363197866',
#  '363197878',
#  '363197879',
#  '363197880',
#  '363197881',
#  '363197883',
#  '363197885',
#  '363197888',
#  '363197889',
#  '363197891',
#  '363198182',
#  '363198183',
#  '363198184',
#  '363198185',
#  '363198186',
#  '363198187',
#  '363198188',
#  '363198189',
#  '363198194',
#  '363198195',
#  '363198196',
#  '363198197'}
